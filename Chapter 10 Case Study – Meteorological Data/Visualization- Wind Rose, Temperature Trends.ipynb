# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('ancona_weather.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)
df[['TMIN', 'TMAX']].plot(title='Temperature Range Over Time')
# Out:
# <Axes: title={'center': 'Temperature Range Over Time'}, xlabel='DATE'>

# %%
import pandas as pd
from windrose import WindroseAxes
import matplotlib.pyplot as plt

df = pd.read_csv("wind_data.csv")  

ax = WindroseAxes.from_ax()
ax.bar(df['wind_dir'], df['wind_speed'], normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
