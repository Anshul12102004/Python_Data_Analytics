# %%
import pandas as pd
import matplotlib.pyplot as plt

a = pd.read_csv('ancona_weather.csv')
c = pd.read_csv('cremona_weather.csv')

a['TAVG'].hist(alpha=0.5, label='Ancona')
c['TAVG'].hist(alpha=0.5, label='Cremona')
plt.legend()
plt.title('Temperature Distribution Comparison')
plt.xlabel('Avg Temp (°C)')
plt.ylabel('Frequency')
plt.show()
