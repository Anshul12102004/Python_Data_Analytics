# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('ancona_weather.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.fillna(method='ffill', inplace=True)
df.set_index('DATE', inplace=True)
df[['TMIN','TMAX']].plot()
# Out:
# /tmp/ipykernel_67227/2184350430.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# <Axes: xlabel='DATE'>
